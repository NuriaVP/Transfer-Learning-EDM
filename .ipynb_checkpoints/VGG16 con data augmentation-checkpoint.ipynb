# %%
import os
import cv2
import seaborn as sn 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import numpy as np
import glob as glob
from sklearn.model_selection import train_test_split
import csv
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report  
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.utils import class_weight
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn.utils import class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
color = 'rgb' #'grayscale' o 'rgb'

escala = 150

# %%
def cargar_datos(path1, path2, escala = escala, color = color):
    
    EMD = os.listdir(path1)
    NO_EMD = os.listdir(path2)
    
    data = []
    labels = []

    for i in EMD:   
        image=tf.keras.preprocessing.image.load_img(path1+'/'+i, color_mode= color, 
        target_size= (escala, escala))
        image=np.array(image)
        data.append(image)
        labels.append(1)
    for i in NO_EMD:   
        image=tf.keras.preprocessing.image.load_img(path2+'/'+i, color_mode= color, 
        target_size= (escala, escala))
        image=np.array(image)
        data.append(image)
        labels.append(0)
        
    data = np.array(data)
    labels = np.array(labels)
    
    return data, labels

# %% [markdown]
# ## Train_generator

# %% [markdown]
# **Data Augmentation**

# %%
datagen = ImageDataGenerator(rotation_range=10, # rotation
                                width_shift_range=0.2, # horizontal shift
                                height_shift_range=0.2, # vertical shift
                                zoom_range=0.2, # zoom
                                horizontal_flip=True, # horizontal flip
                                brightness_range=[0.2,1.2]) # brightness)

# %%
train_generator = datagen.flow_from_directory(directory="Data Augmentation EMD/train",
                                              target_size=(escala, escala), # resize to this size
                                              color_mode=color, # for coloured images
                                              seed=42, # to make the result reproducible
                                              batch_size = 1024
                                              )
# Out:
# Found 267 images belonging to 2 classes.

# %%
val_generator = datagen.flow_from_directory(
                  directory="Data Augmentation EMD/validation",
                  target_size=(escala, escala), # resize to this size
                  color_mode=color, # for coloured images
                  seed=42, # to make the result reproducible
                  batch_size = 256
                  )
# Out:
# Found 67 images belonging to 2 classes.

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ### TRAIN: OCT + Samsung
#
# ### TEST: iPhone

# %% [markdown]
# Habrá que emplear fit_generator() en vez de fit().
#
# https://www.geeksforgeeks.org/keras-fit-and-keras-fit_generator/

# %% [markdown]
# Coloco en test la imágenes de Iphone.

# %% [markdown]
# Datos con preprocesamiento gaussiano.

# %% [markdown]
# No utilizo class_weight_compute().

# %%
dataset_train = cargar_datos('Data Augmentation EMD/train/EMD', 'Data Augmentation EMD/train/NO EMD')

# %%
dataset_test = cargar_datos('Data Augmentation EMD/test/EMD', 'Data Augmentation EMD/test/NO EMD')

# %%
train_ds = dataset_train[0]

train_labels = dataset_train[1]

# %%
test_ds = dataset_test[0]

test_labels = dataset_test[1]

# %%
train_labels_categorical = to_categorical(train_labels, num_classes=2)
test_labels_categorical = to_categorical(test_labels, num_classes=2)

# %%
## Loading VGG16 model
base_model = VGG16(weights="imagenet", include_top=False, input_shape=train_ds[0].shape)
base_model.trainable = False ## Not trainable weights

## Preprocessing input
train_ds = preprocess_input(train_ds) 
test_ds = preprocess_input(test_ds)

# %%
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(2, activation='softmax')


model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# %%
'''
classes = np.unique(train_labels)

class_weights = class_weight.compute_class_weight('balanced', classes=classes, y=train_labels)

dic_class_weights = {0:class_weights[0], 1:class_weights[1]}
'''

# %%
from tensorflow.keras.callbacks import EarlyStopping

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

es = EarlyStopping(monitor='val_accuracy', mode='max', patience=20,  restore_best_weights=True)

history = model.fit_generator(train_generator, epochs=200, callbacks=[es], validation_data=val_generator)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7160\2521339205.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, epochs=200, callbacks=[es], validation_data=val_generator)
# Epoch 1/200
# 1/1 [==============================] - 32s 32s/step - loss: 2.0853 - accuracy: 0.5618 - val_loss: 2.4668 - val_accuracy: 0.7164
# Epoch 2/200
# 1/1 [==============================] - 27s 27s/step - loss: 2.3816 - accuracy: 0.7004 - val_loss: 4.6050 - val_accuracy: 0.2985
# Epoch 3/200
# 1/1 [==============================] - 26s 26s/step - loss: 4.5613 - accuracy: 0.3146 - val_loss: 1.3668 - val_accuracy: 0.7015
# Epoch 4/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.3755 - accuracy: 0.7079 - val_loss: 1.8475 - val_accuracy: 0.7015
# Epoch 5/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.9301 - accuracy: 0.7341 - val_loss: 1.8338 - val_accuracy: 0.7164
# Epoch 6/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.7481 - accuracy: 0.7303 - val_loss: 1.4317 - val_accuracy: 0.7612
# Epoch 7/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.3212 - accuracy: 0.7004 - val_loss: 1.0191 - val_accuracy: 0.6418
# Epoch 8/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.9371 - accuracy: 0.6292 - val_loss: 1.3469 - val_accuracy: 0.4776
# Epoch 9/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.2438 - accuracy: 0.5318 - val_loss: 1.0208 - val_accuracy: 0.5522
# Epoch 10/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.9756 - accuracy: 0.5843 - val_loss: 0.8622 - val_accuracy: 0.7612
# Epoch 11/200
# 1/1 [==============================] - 28s 28s/step - loss: 0.7535 - accuracy: 0.6742 - val_loss: 0.8017 - val_accuracy: 0.7015
# Epoch 12/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.7733 - accuracy: 0.7041 - val_loss: 0.8350 - val_accuracy: 0.7612
# Epoch 13/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.8780 - accuracy: 0.7303 - val_loss: 0.9598 - val_accuracy: 0.7015
# Epoch 14/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.7764 - accuracy: 0.7453 - val_loss: 0.7902 - val_accuracy: 0.7015
# Epoch 15/200
# 1/1 [==============================] - 28s 28s/step - loss: 0.6841 - accuracy: 0.7154 - val_loss: 0.6507 - val_accuracy: 0.7612
# Epoch 16/200
# 1/1 [==============================] - 30s 30s/step - loss: 0.6747 - accuracy: 0.7303 - val_loss: 0.9171 - val_accuracy: 0.6269
# Epoch 17/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.7477 - accuracy: 0.6479 - val_loss: 0.7194 - val_accuracy: 0.6716
# Epoch 18/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.7314 - accuracy: 0.6442 - val_loss: 0.6540 - val_accuracy: 0.7164
# Epoch 19/200
# 1/1 [==============================] - 29s 29s/step - loss: 0.6924 - accuracy: 0.7154 - val_loss: 0.8073 - val_accuracy: 0.7164
# Epoch 20/200
# 1/1 [==============================] - 28s 28s/step - loss: 0.6783 - accuracy: 0.7453 - val_loss: 1.0568 - val_accuracy: 0.7015
# Epoch 21/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.6462 - accuracy: 0.7416 - val_loss: 0.8735 - val_accuracy: 0.7313
# Epoch 22/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.7588 - accuracy: 0.7266 - val_loss: 0.6269 - val_accuracy: 0.7463
# Epoch 23/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6597 - accuracy: 0.7453 - val_loss: 0.7600 - val_accuracy: 0.6716
# Epoch 24/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.5911 - accuracy: 0.7491 - val_loss: 0.7156 - val_accuracy: 0.6716
# Epoch 25/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6084 - accuracy: 0.7303 - val_loss: 0.9019 - val_accuracy: 0.6269
# Epoch 26/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6986 - accuracy: 0.6742 - val_loss: 0.7832 - val_accuracy: 0.5970

# %%
plt.figure(0)  
plt.plot(history.history['accuracy'],'r')  
plt.plot(history.history['val_accuracy'],'g')  
plt.xticks(np.arange(0, 50, 5.0))  
plt.rcParams['figure.figsize'] = (8, 6)  
plt.xlabel("Num of Epochs")  
plt.ylabel("Accuracy")  
plt.title("Training Accuracy vs Validation Accuracy")  
plt.legend(['train','validation'])

plt.figure(1)  
plt.plot(history.history['loss'],'r')  
plt.plot(history.history['val_loss'],'g')  
plt.xticks(np.arange(0, 50, 5.0))  
plt.rcParams['figure.figsize'] = (8, 6)  
plt.xlabel("Num of Epochs")  
plt.ylabel("Loss")  
plt.title("Training Loss vs Validation Loss")  
plt.legend(['train','validation'])

plt.show()

# %%
acc      = history.history['accuracy']
val_acc  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Entrenamiento acc')
plt.plot(epochs, val_acc, 'b', label='Validación acc')
plt.title('Accuracy - exactitud de entrenamiento y validación')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Entrenamiento loss')
plt.plot(epochs, val_loss, 'b', label='Validación loss')
plt.title('Loss - función objetivo en entrenamiento y prueba')
plt.legend()

plt.show()

# %%
vgg16 = model.predict(test_ds, batch_size=32, verbose=1)  
vgg16_predicted = np.argmax(vgg16, axis=1)

vgg_cm = confusion_matrix(np.argmax(test_labels_categorical, axis=1), vgg16_predicted)

# Visualizing of confusion matrix
vgg_df_cm = pd.DataFrame(vgg_cm, range(2), range(2))  
plt.figure(figsize = (20,14))  
sn.set(font_scale=1.4) #for label size  
sn.heatmap(vgg_df_cm, annot=True, annot_kws={"size": 12}) # font size  
plt.show()
# Out:
# 4/4 [==============================] - 5s 1s/step

# %% [markdown]
# **MÉTRICAS DE EVALUACIÓN**

# %%
score_test = model.evaluate(x=test_ds, y=test_labels_categorical, verbose = 0)

print("Test loss:", score_test[0])
print("Test accuracy:", score_test[1])
# Out:
# Test loss: 5.783105373382568
# Test accuracy: 0.2589285671710968

# %%
predictions = model.predict(test_ds)
# Out:
# 4/4 [==============================] - 4s 1s/step

# %%
roc_score = roc_auc_score(test_labels_categorical, predictions, multi_class='ovr')

print(roc_score)
# Out:
# 0.4146471088435374

# %%
snn_predicted = np.argmax(predictions, axis=1)
snn_report = classification_report(np.argmax(test_labels_categorical, axis=1), snn_predicted)  
print(snn_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.02        84
#            1       0.25      1.00      0.40        28
#
#     accuracy                           0.26       112
#    macro avg       0.63      0.51      0.21       112
# weighted avg       0.81      0.26      0.12       112

# %% [markdown]
# ### TRAIN: OCT + iPhone
#
# ### TEST: Samsung

# %% [markdown]
# Coloco en test la imágenes de Samsung.

# %% [markdown]
# Con datos de preprocesamiento gaussiano.

# %%
dataset_train = cargar_datos('Data Augmentation EMD/train/EMD', 'Data Augmentation EMD/train/NO EMD')

# %%
dataset_test = cargar_datos('Data Augmentation EMD/test/EMD', 'Data Augmentation EMD/test/NO EMD')

# %%
train_ds = dataset_train[0]

train_labels = dataset_train[1]

# %%
test_ds = dataset_test[0]

test_labels = dataset_test[1]

# %%
train_labels_categorical = to_categorical(train_labels, num_classes=2)
test_labels_categorical = to_categorical(test_labels, num_classes=2)

# %%
## Loading VGG16 model
base_model = VGG16(weights="imagenet", include_top=False, input_shape=train_ds[0].shape)
base_model.trainable = False ## Not trainable weights

## Preprocessing input
train_ds = preprocess_input(train_ds) 
test_ds = preprocess_input(test_ds)

# %%
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(2, activation='softmax')


model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# %%
classes = np.unique(train_labels)

class_weights = class_weight.compute_class_weight('balanced', classes=classes, y=train_labels)

dic_class_weights = {0:class_weights[0], 1:class_weights[1]}

# %%
from tensorflow.keras.callbacks import EarlyStopping

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

es = EarlyStopping(monitor='val_accuracy', mode='max', patience=20,  restore_best_weights=True)

history = model.fit_generator(train_generator, epochs=200, callbacks=[es], validation_data=val_generator, class_weight=dic_class_weights)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_7160\626540249.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, epochs=200, callbacks=[es], validation_data=val_generator, class_weight=dic_class_weights)
# Epoch 1/200
# 1/1 [==============================] - 31s 31s/step - loss: 3.3740 - accuracy: 0.5805 - val_loss: 16.7187 - val_accuracy: 0.7313
# Epoch 2/200
# 1/1 [==============================] - 26s 26s/step - loss: 9.1611 - accuracy: 0.7303 - val_loss: 7.3490 - val_accuracy: 0.7313
# Epoch 3/200
# 1/1 [==============================] - 27s 27s/step - loss: 4.5275 - accuracy: 0.7303 - val_loss: 2.5368 - val_accuracy: 0.7612
# Epoch 4/200
# 1/1 [==============================] - 31s 31s/step - loss: 2.6071 - accuracy: 0.7079 - val_loss: 2.0725 - val_accuracy: 0.6866
# Epoch 5/200
# 1/1 [==============================] - 27s 27s/step - loss: 2.5077 - accuracy: 0.5918 - val_loss: 2.4644 - val_accuracy: 0.7313
# Epoch 6/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.7593 - accuracy: 0.7303 - val_loss: 1.6847 - val_accuracy: 0.7164
# Epoch 7/200
# 1/1 [==============================] - 27s 27s/step - loss: 1.3589 - accuracy: 0.7191 - val_loss: 1.1915 - val_accuracy: 0.7164
# Epoch 8/200
# 1/1 [==============================] - 28s 28s/step - loss: 1.6166 - accuracy: 0.6067 - val_loss: 0.9835 - val_accuracy: 0.7612
# Epoch 9/200
# 1/1 [==============================] - 28s 28s/step - loss: 1.2159 - accuracy: 0.6929 - val_loss: 1.4032 - val_accuracy: 0.7761
# Epoch 10/200
# 1/1 [==============================] - 30s 30s/step - loss: 1.2081 - accuracy: 0.7041 - val_loss: 1.9512 - val_accuracy: 0.7313
# Epoch 11/200
# 1/1 [==============================] - 34s 34s/step - loss: 1.2005 - accuracy: 0.7004 - val_loss: 1.2244 - val_accuracy: 0.7761
# Epoch 12/200
# 1/1 [==============================] - 30s 30s/step - loss: 1.2836 - accuracy: 0.7228 - val_loss: 0.9595 - val_accuracy: 0.7612
# Epoch 13/200
# 1/1 [==============================] - 28s 28s/step - loss: 1.4324 - accuracy: 0.7191 - val_loss: 1.6436 - val_accuracy: 0.7313
# Epoch 14/200
# 1/1 [==============================] - 29s 29s/step - loss: 1.0545 - accuracy: 0.7041 - val_loss: 1.3912 - val_accuracy: 0.7612
# Epoch 15/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.9476 - accuracy: 0.7378 - val_loss: 1.0701 - val_accuracy: 0.7463
# Epoch 16/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.0217 - accuracy: 0.7416 - val_loss: 1.2921 - val_accuracy: 0.7015
# Epoch 17/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.9158 - accuracy: 0.7041 - val_loss: 0.7594 - val_accuracy: 0.7164
# Epoch 18/200
# 1/1 [==============================] - 28s 28s/step - loss: 0.9125 - accuracy: 0.7041 - val_loss: 1.0952 - val_accuracy: 0.6418
# Epoch 19/200
# 1/1 [==============================] - 29s 29s/step - loss: 0.7424 - accuracy: 0.7528 - val_loss: 0.9619 - val_accuracy: 0.6866
# Epoch 20/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.7889 - accuracy: 0.7678 - val_loss: 1.0015 - val_accuracy: 0.6866
# Epoch 21/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.7216 - accuracy: 0.7715 - val_loss: 1.1121 - val_accuracy: 0.7612
# Epoch 22/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.7248 - accuracy: 0.7453 - val_loss: 0.9117 - val_accuracy: 0.6866
# Epoch 23/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6705 - accuracy: 0.7453 - val_loss: 0.9079 - val_accuracy: 0.7164
# Epoch 24/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6191 - accuracy: 0.7865 - val_loss: 0.7824 - val_accuracy: 0.6716
# Epoch 25/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.7231 - accuracy: 0.7678 - val_loss: 1.1234 - val_accuracy: 0.6418
# Epoch 26/200
# 1/1 [==============================] - 27s 27s/step - loss: 0.7498 - accuracy: 0.7528 - val_loss: 0.9384 - val_accuracy: 0.7164
# Epoch 27/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6617 - accuracy: 0.7753 - val_loss: 0.7848 - val_accuracy: 0.7313
# Epoch 28/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6197 - accuracy: 0.7528 - val_loss: 1.1006 - val_accuracy: 0.7015
# Epoch 29/200
# 1/1 [==============================] - 26s 26s/step - loss: 0.6356 - accuracy: 0.7416 - val_loss: 1.0848 - val_accuracy: 0.6866

# %%
plt.figure(0)  
plt.plot(history.history['accuracy'],'r')  
plt.plot(history.history['val_accuracy'],'g')  
plt.xticks(np.arange(0, 50, 5.0))  
plt.rcParams['figure.figsize'] = (8, 6)  
plt.xlabel("Num of Epochs")  
plt.ylabel("Accuracy")  
plt.title("Training Accuracy vs Validation Accuracy")  
plt.legend(['train','validation'])

plt.figure(1)  
plt.plot(history.history['loss'],'r')  
plt.plot(history.history['val_loss'],'g')  
plt.xticks(np.arange(0, 50, 5.0))  
plt.rcParams['figure.figsize'] = (8, 6)  
plt.xlabel("Num of Epochs")  
plt.ylabel("Loss")  
plt.title("Training Loss vs Validation Loss")  
plt.legend(['train','validation'])

plt.show()

# %%
acc      = history.history['accuracy']
val_acc  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Entrenamiento acc')
plt.plot(epochs, val_acc, 'b', label='Validación acc')
plt.title('Accuracy - exactitud de entrenamiento y validación')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Entrenamiento loss')
plt.plot(epochs, val_loss, 'b', label='Validación loss')
plt.title('Loss - función objetivo en entrenamiento y prueba')
plt.legend()

plt.show()

# %%
vgg16 = model.predict(test_ds, batch_size=32, verbose=1)  
vgg16_predicted = np.argmax(vgg16, axis=1)

vgg_cm = confusion_matrix(np.argmax(test_labels_categorical, axis=1), vgg16_predicted)

# Visualizing of confusion matrix
vgg_df_cm = pd.DataFrame(vgg_cm, range(2), range(2))  
plt.figure(figsize = (20,14))  
sn.set(font_scale=1.4) #for label size  
sn.heatmap(vgg_df_cm, annot=True, annot_kws={"size": 12}) # font size  
plt.show()
# Out:
# 4/4 [==============================] - 4s 960ms/step

# %% [markdown]
# **MÉTRICAS DE EVALUACIÓN**

# %%
score_test = model.evaluate(x=test_ds, y=test_labels_categorical, verbose = 0)

print("Test loss:", score_test[0])
print("Test accuracy:", score_test[1])
# Out:
# Test loss: 3.7730984687805176
# Test accuracy: 0.3962264060974121

# %%
predictions = model.predict(test_ds)
# Out:
# 4/4 [==============================] - 4s 949ms/step

# %%
roc_score = roc_auc_score(test_labels_categorical, predictions, multi_class='ovr')

print(roc_score)
# Out:
# 0.49230205278592376

# %%
snn_predicted = np.argmax(predictions, axis=1)
snn_report = classification_report(np.argmax(test_labels_categorical, axis=1), snn_predicted)  
print(snn_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.02      0.03        62
#            1       0.40      0.93      0.56        44
#
#     accuracy                           0.40       106
#    macro avg       0.33      0.47      0.30       106
# weighted avg       0.31      0.40      0.25       106
