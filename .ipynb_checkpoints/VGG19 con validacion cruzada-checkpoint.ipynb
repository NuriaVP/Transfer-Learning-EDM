# %%
import os
import cv2
import seaborn as sn 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import numpy as np
import glob as glob
from sklearn.model_selection import train_test_split
import csv
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report  
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.utils import class_weight
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from keras.applications.vgg19 import VGG19
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score

# %%
color = 'rgb' #'grayscale' o 'rgb'

escala = 150

# %%
def cargar_datos(path1, path2, escala = escala, color = color):
    
    EMD = os.listdir(path1)
    NO_EMD = os.listdir(path2)
    
    data = []
    labels = []

    for i in EMD:   
        image=tf.keras.preprocessing.image.load_img(path1+'/'+i, color_mode= color, 
        target_size= (escala, escala))
        image=np.array(image)
        data.append(image)
        labels.append(1)
    for i in NO_EMD:   
        image=tf.keras.preprocessing.image.load_img(path2+'/'+i, color_mode= color, 
        target_size= (escala, escala))
        image=np.array(image)
        data.append(image)
        labels.append(0)
        
    data = np.array(data)
    labels = np.array(labels)
    
    return data, labels

# %%
dataset_iphone = cargar_datos('Datos preprocesados INP EMD/iPhone/EMD', 'Datos preprocesados INP EMD/iPhone/NO EMD')

# %%
dataset_samsung = cargar_datos('Datos preprocesados INP EMD/Samsung/EMD', 'Datos preprocesados INP EMD/Samsung/NO EMD')

# %%
dataset = cargar_datos('Datos preprocesados INP EMD/OCT/EMD', 'Datos preprocesados INP EMD/OCT/NO EMD')

# %% [markdown]
# https://scikit-learn.org/stable/modules/cross_validation.html

# %% [markdown]
# **DIVISIÓN TRAIN Y TEST**

# %%
X = np.concatenate((dataset[0],dataset_samsung[0]))

X = np.concatenate((X,dataset_iphone[0]))

y = np.concatenate((dataset[1],dataset_samsung[1]))

y = np.concatenate((y,dataset_iphone[1]))

# %% [markdown]
# **REDIMENSIONAR DATOS TRAIN A 2D**

# %%
'''
nsamples, nx, ny, nz = X.shape
X = X.reshape((nsamples,nx*ny*nz))
'''
# Out:
# '\nnsamples, nx, ny, nz = X.shape\nX = X.reshape((nsamples,nx*ny*nz))\n'

# %% [markdown]
# **GENERAR GRUPO TRAIN Y TEST ALEATORIAMENTE**

# %%
'''
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)
'''
# Out:
# '\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)\n'

# %% [markdown]
# **DEFINICIÓN DEL MODELO**

# %%
'''
train_labels_categorical = to_categorical(y_train, num_classes=2)
test_labels_categorical = to_categorical(y_test, num_classes=2)
'''
# Out:
# '\ntrain_labels_categorical = to_categorical(y_train, num_classes=2)\ntest_labels_categorical = to_categorical(y_test, num_classes=2)\n'

# %%
'''
X_train = preprocess_input(X_train) 
y_train = preprocess_input(y_train)
'''
# Out:
# '\nX_train = preprocess_input(X_train) \ny_train = preprocess_input(y_train)\n'

# %%
class KerasModel(BaseEstimator, ClassifierMixin):
    
    dataset_iphone = cargar_datos('Datos preprocesados INP EMD/iPhone/EMD', 'Datos preprocesados INP EMD/iPhone/NO EMD')
    dataset_samsung = cargar_datos('Datos preprocesados INP EMD/Samsung/EMD', 'Datos preprocesados INP EMD/Samsung/NO EMD')
    dataset = cargar_datos('Datos preprocesados INP EMD/OCT/EMD', 'Datos preprocesados INP EMD/OCT/NO EMD')
    
    X = np.concatenate((dataset[0],dataset_samsung[0]))

    X = np.concatenate((X,dataset_iphone[0]))

    y = np.concatenate((dataset[1],dataset_samsung[1]))

    y = np.concatenate((y,dataset_iphone[1]))
    '''
    nsamples, nx, ny, nz = X.shape
    X = X.reshape((nsamples,nx*ny*nz))
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)
    
    def fit(self, X_train, y_train):
        
        train_labels_categorical = to_categorical(y_train, num_classes=2)
        
        X_train = preprocess_input(X_train) 
        y_train = preprocess_input(y_train)
        
        ## Loading VGG16 model
        base_model = VGG19(weights="imagenet", include_top=False, input_shape=X_train[0].shape)
        base_model.trainable = False ## Not trainable weights
        
        flatten_layer = layers.Flatten()
        dense_layer_1 = layers.Dense(50, activation='relu')
        dense_layer_2 = layers.Dense(20, activation='relu')
        prediction_layer = layers.Dense(2, activation='softmax')

        model = models.Sequential([
            base_model,
            flatten_layer,
            dense_layer_1,
            dense_layer_2,
            prediction_layer
        ])
        
        classes = np.unique(y_train)
        class_weights = class_weight.compute_class_weight('balanced', classes=classes, y=y_train)
        dic_class_weights = {0:class_weights[0], 1:class_weights[1]}
        
        model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy'],
        )

        es = EarlyStopping(monitor='val_accuracy', mode='max', patience=20,  restore_best_weights=True)

        model.fit(x=X_train,y=train_labels_categorical, epochs=200, validation_split=0.2, batch_size=32, callbacks=[es], class_weight=dic_class_weights)

        self.model = model
        
        return self
    
    def score(self, X_test, y_test):
        
        predictions = self.model.predict(X_test)
        y_pred = []
        
        for e in predictions:
            if e[0]>e[1]:
                y_pred.append(0)
            else:
                y_pred.append(1)
                
        return accuracy_score(y_test, y_pred)
    
    def predict(self, X_test):
                
        return self.model.predict(X_test)

# %% [markdown]
# **VALIDACIÓN CRUZADA**

# %% [markdown]
# Evaluar una puntuación mediante validación cruzada.
#
# Devuelve una matriz de puntuaciones del estimador para cada ejecución de la validación cruzada (en este caso hacemos 5).

# %%
clf = KerasModel()

# %%
scores = cross_val_score(clf, X, y)

print(scores)

print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Epoch 1/200
# 7/7 [==============================] - 13s 2s/step - loss: 191.5676 - accuracy: 0.5231 - val_loss: 0.1237 - val_accuracy: 1.0000
# Epoch 2/200
# 7/7 [==============================] - 12s 2s/step - loss: 40.2658 - accuracy: 0.6359 - val_loss: 0.7729 - val_accuracy: 0.1020
# Epoch 3/200
# 7/7 [==============================] - 15s 2s/step - loss: 30.4692 - accuracy: 0.5077 - val_loss: 0.9636 - val_accuracy: 0.4286
# Epoch 4/200
# 7/7 [==============================] - 14s 2s/step - loss: 28.5177 - accuracy: 0.6974 - val_loss: 0.7912 - val_accuracy: 0.6939
# Epoch 5/200
# 7/7 [==============================] - 14s 2s/step - loss: 25.1700 - accuracy: 0.7897 - val_loss: 1.1643 - val_accuracy: 0.3061
# Epoch 6/200
# 7/7 [==============================] - 14s 2s/step - loss: 21.8641 - accuracy: 0.7897 - val_loss: 0.8377 - val_accuracy: 0.6327
# Epoch 7/200
# 7/7 [==============================] - 14s 2s/step - loss: 22.0547 - accuracy: 0.7795 - val_loss: 0.6506 - val_accuracy: 0.7959
# 7/7 [==============================] - 14s 2s/step - loss: 6.1370 - accuracy: 0.9487 - val_loss: 3.8523 - val_accuracy: 0.3878
# Epoch 7/200
# 7/7 [==============================] - 15s 2s/step - loss: 13.4491 - accuracy: 0.9128 - val_loss: 0.2080 - val_accuracy: 0.9184
# Epoch 8/200
# 7/7 [==============================] - 14s 2s/step - loss: 23.9191 - accuracy: 0.8667 - val_loss: 7.1622 - val_accuracy: 0.2857
# Epoch 9/200
# 7/7 [==============================] - 15s 2s/step - loss: 12.4880 - accuracy: 0.9282 - val_loss: 1.6929 - val_accuracy: 0.6122
# Epoch 10/200
# 7/7 [==============================] - 15s 2s/step - loss: 20.6379 - accuracy: 0.8872 - val_loss: 0.4807 - val_accuracy: 0.8367
# Epoch 11/200
# 7/7 [==============================] - 15s 2s/step - loss: 13.5946 - accuracy: 0.9282 - val_loss: 5.4894 - val_accuracy: 0.3673
# Epoch 12/200
# 7/7 [==============================] - 15s 2s/step - loss: 7.3410 - accuracy: 0.9385 - val_loss: 0.4842 - val_accuracy: 0.7959
# Epoch 13/200
# 7/7 [==============================] - 15s 2s/step - loss: 4.6916 - accuracy: 0.9590 - val_loss: 2.3573 - val_accuracy: 0.5102
# Epoch 14/200
# 7/7 [==============================] - 15s 2s/step - loss: 3.4292 - accuracy: 0.9692 - val_loss: 2.5844 - val_accuracy: 0.4898
# Epoch 15/200
# 7/7 [==============================] - 15s 2s/step - loss: 1.7910 - accuracy: 0.9795 - val_loss: 1.4634 - val_accuracy: 0.6327
# Epoch 16/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.1983 - accuracy: 1.0000 - val_loss: 3.3251 - val_accuracy: 0.4082
# Epoch 17/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.1935 - accuracy: 1.0000 - val_loss: 3.8550 - val_accuracy: 0.3673
# Epoch 18/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.1277 - accuracy: 1.0000 - val_loss: 3.0365 - val_accuracy: 0.4286
# Epoch 19/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 2.3631 - val_accuracy: 0.5306
# Epoch 20/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 2.0595 - val_accuracy: 0.5714
# Epoch 21/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.9734 - val_accuracy: 0.5918
# Epoch 22/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 1.9985 - val_accuracy: 0.5918
# Epoch 23/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 2.0730 - val_accuracy: 0.5714
# Epoch 24/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 2.1544 - val_accuracy: 0.5714
# Epoch 25/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 2.2183 - val_accuracy: 0.5714
# Epoch 26/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 2.2875 - val_accuracy: 0.5714
# Epoch 27/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 2.3331 - val_accuracy: 0.5714
# 2/2 [==============================] - 4s 2s/step
# Epoch 1/200
# 7/7 [==============================] - 16s 2s/step - loss: 116.5849 - accuracy: 0.5795 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 2/200
# 7/7 [==============================] - 15s 2s/step - loss: 62.4007 - accuracy: 0.6205 - val_loss: 0.6663 - val_accuracy: 0.6939
# Epoch 3/200
# 7/7 [==============================] - 15s 2s/step - loss: 35.8567 - accuracy: 0.7590 - val_loss: 0.2378 - val_accuracy: 0.8980
# Epoch 4/200
# 7/7 [==============================] - 15s 2s/step - loss: 33.8693 - accuracy: 0.8103 - val_loss: 4.0026 - val_accuracy: 0.0612
# Epoch 5/200
# 7/7 [==============================] - 15s 2s/step - loss: 37.7288 - accuracy: 0.7795 - val_loss: 1.0257 - val_accuracy: 0.6122
# Epoch 6/200
# 7/7 [==============================] - 15s 2s/step - loss: 26.3697 - accuracy: 0.7897 - val_loss: 0.1504 - val_accuracy: 0.9388
# Epoch 7/200
# 7/7 [==============================] - 16s 2s/step - loss: 22.7104 - accuracy: 0.8718 - val_loss: 3.4611 - val_accuracy: 0.2041
# Epoch 8/200
# 7/7 [==============================] - 15s 2s/step - loss: 14.0000 - accuracy: 0.9128 - val_loss: 0.6384 - val_accuracy: 0.8163
# Epoch 9/200
# 7/7 [==============================] - 15s 2s/step - loss: 6.4515 - accuracy: 0.9590 - val_loss: 2.5755 - val_accuracy: 0.4082
# Epoch 10/200
# 7/7 [==============================] - 15s 2s/step - loss: 8.4197 - accuracy: 0.9179 - val_loss: 0.4182 - val_accuracy: 0.8776
# Epoch 11/200
# 7/7 [==============================] - 15s 2s/step - loss: 5.2870 - accuracy: 0.9590 - val_loss: 2.0848 - val_accuracy: 0.4694
# Epoch 12/200
# 7/7 [==============================] - 15s 2s/step - loss: 3.2704 - accuracy: 0.9692 - val_loss: 0.7469 - val_accuracy: 0.7959
# Epoch 13/200
# 7/7 [==============================] - 15s 2s/step - loss: 2.4326 - accuracy: 0.9846 - val_loss: 1.5191 - val_accuracy: 0.5918
# Epoch 14/200
# 7/7 [==============================] - 15s 2s/step - loss: 1.0757 - accuracy: 1.0000 - val_loss: 0.8543 - val_accuracy: 0.7755
# Epoch 15/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.9927 - accuracy: 0.9949 - val_loss: 1.0617 - val_accuracy: 0.7551
# Epoch 16/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.7265 - accuracy: 1.0000 - val_loss: 0.8909 - val_accuracy: 0.7551
# Epoch 17/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.6776 - accuracy: 1.0000 - val_loss: 0.9754 - val_accuracy: 0.7551
# Epoch 18/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.6407 - accuracy: 1.0000 - val_loss: 1.0939 - val_accuracy: 0.7551
# Epoch 19/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.5794 - accuracy: 1.0000 - val_loss: 0.9607 - val_accuracy: 0.7551
# Epoch 20/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.5868 - accuracy: 1.0000 - val_loss: 1.1234 - val_accuracy: 0.7143
# Epoch 21/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.5474 - accuracy: 1.0000 - val_loss: 1.1789 - val_accuracy: 0.6939
# 2/2 [==============================] - 4s 2s/step
# Epoch 1/200
# 7/7 [==============================] - 15s 2s/step - loss: 247.3535 - accuracy: 0.6256 - val_loss: 3.9341 - val_accuracy: 0.3878
# Epoch 2/200
# 7/7 [==============================] - 15s 2s/step - loss: 53.1094 - accuracy: 0.7436 - val_loss: 6.4289 - val_accuracy: 0.1633
# Epoch 3/200
# 7/7 [==============================] - 15s 2s/step - loss: 31.0063 - accuracy: 0.8103 - val_loss: 3.8867 - val_accuracy: 0.3265
# Epoch 4/200
# 7/7 [==============================] - 15s 2s/step - loss: 27.4592 - accuracy: 0.8462 - val_loss: 3.8351 - val_accuracy: 0.3673
# Epoch 5/200
# 7/7 [==============================] - 15s 2s/step - loss: 11.9153 - accuracy: 0.9077 - val_loss: 3.9763 - val_accuracy: 0.3265
# Epoch 6/200
# 7/7 [==============================] - 14s 2s/step - loss: 10.7935 - accuracy: 0.9077 - val_loss: 4.8470 - val_accuracy: 0.2245
# Epoch 7/200
# 7/7 [==============================] - 14s 2s/step - loss: 3.9079 - accuracy: 0.9744 - val_loss: 9.3401 - val_accuracy: 0.1429
# Epoch 8/200
# 7/7 [==============================] - 14s 2s/step - loss: 30.5205 - accuracy: 0.8410 - val_loss: 1.3058 - val_accuracy: 0.6939
# Epoch 9/200
# 7/7 [==============================] - 14s 2s/step - loss: 30.1095 - accuracy: 0.8410 - val_loss: 1.9138 - val_accuracy: 0.5918
# Epoch 10/200
# 7/7 [==============================] - 14s 2s/step - loss: 33.6980 - accuracy: 0.9026 - val_loss: 9.8317 - val_accuracy: 0.2245
# Epoch 11/200
# 7/7 [==============================] - 14s 2s/step - loss: 9.4501 - accuracy: 0.9333 - val_loss: 1.7391 - val_accuracy: 0.6735
# Epoch 12/200
# 7/7 [==============================] - 14s 2s/step - loss: 3.2343 - accuracy: 0.9846 - val_loss: 5.4404 - val_accuracy: 0.3469
# Epoch 13/200
# 7/7 [==============================] - 14s 2s/step - loss: 2.0637 - accuracy: 0.9846 - val_loss: 2.7510 - val_accuracy: 0.6327
# Epoch 14/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.2383 - accuracy: 1.0000 - val_loss: 5.0524 - val_accuracy: 0.3673
# Epoch 15/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.5691 - accuracy: 1.0000 - val_loss: 3.4051 - val_accuracy: 0.5714
# Epoch 16/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.2512 - accuracy: 1.0000 - val_loss: 2.8237 - val_accuracy: 0.6327
# Epoch 17/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.2206 - accuracy: 1.0000 - val_loss: 3.7215 - val_accuracy: 0.5102
# Epoch 18/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 4.4431 - val_accuracy: 0.4082
# Epoch 19/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 4.4948 - val_accuracy: 0.4082
# Epoch 20/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 4.2394 - val_accuracy: 0.4286
# Epoch 21/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 3.9229 - val_accuracy: 0.4898
# Epoch 22/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 3.8075 - val_accuracy: 0.5306
# Epoch 23/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 3.8748 - val_accuracy: 0.4898
# Epoch 24/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 3.9431 - val_accuracy: 0.4898
# Epoch 25/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 3.9768 - val_accuracy: 0.4694
# Epoch 26/200
# 7/7 [==============================] - 15s 2s/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 3.9979 - val_accuracy: 0.4694
# Epoch 27/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 4.0170 - val_accuracy: 0.4694
# Epoch 28/200
# 7/7 [==============================] - 14s 2s/step - loss: 0.0241 - accuracy: 1.0000 - val_loss:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001ACF1F4E040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 4s 2s/step
# [0.73770492 0.73770492 0.73770492 0.68852459 0.73770492]
# 0.73 accuracy with a standard deviation of 0.02

# %% [markdown]
# La cross_validate función se diferencia de cross_val_score dos maneras:
#
# - Permite especificar múltiples métricas para su evaluación.
#
# - Devuelve un dict que contiene tiempos de ajuste, tiempos de puntuación (y, opcionalmente, puntuaciones de entrenamiento, así como estimadores ajustados), además de la puntuación de la prueba.

# %%
'''
print(cross_validate(clf, X, y))
'''
# Out:
# '\nprint(cross_validate(clf, X, y))\n'

# %%
y_pred = cross_val_predict(clf, X, y)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 10s 1s/step - loss: 280.4253 - accuracy: 0.6051 - val_loss: 0.1277 - val_accuracy: 0.9388
# Epoch 2/200
# 7/7 [==============================] - 10s 1s/step - loss: 49.0788 - accuracy: 0.6154 - val_loss: 1.3724 - val_accuracy: 0.3673
# Epoch 3/200
# 7/7 [==============================] - 11s 2s/step - loss: 26.8811 - accuracy: 0.7590 - val_loss: 1.3458 - val_accuracy: 0.4082
# Epoch 4/200
# 7/7 [==============================] - 11s 2s/step - loss: 16.3873 - accuracy: 0.8564 - val_loss: 0.3654 - val_accuracy: 0.8163
# Epoch 5/200
# 7/7 [==============================] - 11s 2s/step - loss: 14.7549 - accuracy: 0.8769 - val_loss: 1.4358 - val_accuracy: 0.3673
# Epoch 6/200
# 7/7 [==============================] - 11s 2s/step - loss: 10.5551 - accuracy: 0.9385 - val_loss: 1.1910 - val_accuracy: 0.4490
# Epoch 7/200
# 7/7 [==============================] - 11s 2s/step - loss: 8.9526 - accuracy: 0.9385 - val_loss: 0.6410 - val_accuracy: 0.7347
# Epoch 8/200
# 7/7 [==============================] - 11s 2s/step - loss: 6.7290 - accuracy: 0.9641 - val_loss: 1.0265 - val_accuracy: 0.5714
# Epoch 9/200
# 7/7 [==============================] - 11s 2s/step - loss: 5.4430 - accuracy: 0.9692 - val_loss: 0.9631 - val_accuracy: 0.5918
# Epoch 10/200
# 7/7 [==============================] - 11s 2s/step - loss: 4.1565 - accuracy: 0.9949 - val_loss: 0.8320 - val_accuracy: 0.6327
# Epoch 11/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.6903 - accuracy: 0.9846 - val_loss: 1.5726 - val_accuracy: 0.4694
# Epoch 12/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.0440 - accuracy: 1.0000 - val_loss: 0.6051 - val_accuracy: 0.7551
# Epoch 13/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.4721 - accuracy: 0.9846 - val_loss: 1.3737 - val_accuracy: 0.5102
# Epoch 14/200
# 7/7 [==============================] - 11s 2s/step - loss: 2.3182 - accuracy: 0.9949 - val_loss: 1.1694 - val_accuracy: 0.5714
# Epoch 15/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.5993 - accuracy: 0.9949 - val_loss: 1.0919 - val_accuracy: 0.5714
# Epoch 16/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3193 - accuracy: 1.0000 - val_loss: 0.9868 - val_accuracy: 0.6122
# Epoch 17/200
# 7/7 [==============================] - 11s 2s/step - loss: 1
200
# 7/7 [==============================] - 11s 2s/step - loss: 1.9277 - accuracy: 0.9949 - val_loss: 1.3578 - val_accuracy: 0.5714
# Epoch 17/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.7116 - accuracy: 1.0000 - val_loss: 1.0409 - val_accuracy: 0.6735
# Epoch 18/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.6701 - accuracy: 0.9949 - val_loss: 1.1364 - val_accuracy: 0.6327
# Epoch 19/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3681 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.6939
# Epoch 20/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.2619 - accuracy: 1.0000 - val_loss: 1.0840 - val_accuracy: 0.6939
# Epoch 21/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4483 - accuracy: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.7347
# Epoch 22/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.0125 - accuracy: 1.0000 - val_loss: 0.7868 - val_accuracy: 0.7959
# Epoch 23/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8997 - accuracy: 1.0000 - val_loss: 1.0337 - val_accuracy: 0.6735
# Epoch 24/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8507 - accuracy: 1.0000 - val_loss: 0.9865 - val_accuracy: 0.7755
# Epoch 25/200
# 7/7 [==============================] - 13s 2s/step - loss: 0.7490 - accuracy: 1.0000 - val_loss: 0.9874 - val_accuracy: 0.7755
# Epoch 26/200
# 7/7 [==============================] - 12s 2s/step - loss: 0.6889 - accuracy: 1.0000 - val_loss: 1.0550 - val_accuracy: 0.7347
# Epoch 27/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7005 - accuracy: 1.0000 - val_loss: 1.0909 - val_accuracy: 0.6939
# Epoch 28/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.6012 - accuracy: 1.0000 - val_loss: 1.1858 - val_accuracy: 0.6735
# Epoch 29/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5760 - accuracy: 1.0000 - val_loss: 1.0458 - val_accuracy: 0.7551
# 2/2 [==============================] - 3s 1s/step
# Epoch 1/200
# 7/7 [==============================] - 13s 2s/step - loss: 127.6441 - accuracy: 0.6154 - val_loss: 1.1453 - val_accuracy: 0.7347
# Epoch 2/200
# 7/7 [==============================] - 12s 2s/step - loss: 68.4042 - accuracy: 0.7026 - val_loss: 2.9076 - val_accuracy: 0.4490
# Epoch 3/200
# 7/7 [==============================] - 11s 2s/step - loss: 35.0707 - accuracy: 0.7949 - val_loss: 2.2635 - val_accuracy: 0.4490
# Epoch 4/200
# 7/7 [==============================] - 12s 2s/step - loss: 26.8557 - accuracy: 0.8051 - val_loss: 7.0693 - val_accuracy: 0.1429
# Epoch 5/200
# 7/7 [==============================] - 12s 2s/step - loss: 19.2473 - accuracy: 0.8667 - val_loss: 3.8017 - val_accuracy: 0.4286
# Epoch 6/200
# 7/7 [==============================] - 12s 2s/step - loss: 17.4543 - accuracy: 0.8821 - val_loss: 4.0632 - val_accuracy: 0.3878
# Epoch 7/200
# 7/7 [==============================] - 12s 2s/step - loss: 20.1476 - accuracy: 0.8923 - val_loss: 7.3548 - val_accuracy: 0.2653
# Epoch 8/200
# 7/7 [==============================] - 12s 2s/step - loss: 8.5468 - accuracy: 0.9026 - val_loss: 6.4328 - val_accuracy: 0.2857
# Epoch 9/200
# 7/7 [==============================] - 12s 2s/step - loss: 13.0398 - accuracy: 0.9282 - val_loss: 7.7682 - val_accuracy: 0.2653
# Epoch 10/200
# 7/7 [==============================] - 11s 2s/step - loss: 4.3300 - accuracy: 0.9692 - val_loss: 3.6996 - val_accuracy: 0.4898
# Epoch 11/200
# 7/7 [==============================] - 12s 2s/step - loss: 9.7235 - accuracy: 0.9282 - val_loss: 8.2414 - val_accuracy: 0.1837
# Epoch 12/200
# 7/7 [==============================] - 11s 2s/step - loss: 2.2795 - accuracy: 0.9846 - val_loss: 8.4628 - val_accuracy: 0.1633
# Epoch 13/200
# 7/7 [==============================] - 11s 2s/step - loss: 5.6655 - accuracy: 0.9436 - val_loss: 3.1672 - val_accuracy: 0.5306
# Epoch 14/200
# 7/7 [==============================] - 11s 2s/step - loss: 15.1607 - accuracy: 0.9026 - val_loss: 8.7814 - val_accuracy: 0.1633
# Epoch 15/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.1550 - accuracy: 0.9949 - val_loss: 3.7658 - val_accuracy: 0.5306
# Epoch 16/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.3862 - accuracy: 0.9795 - val_loss: 7.1818 - val_accuracy: 0.2857
# Epoch 17/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.3988 - accuracy: 0.9949 - val_loss: 5.5572 - val_accuracy: 0.3265
# Epoch 18/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.8243 - accuracy: 0.9949 - val_loss: 4.9568 - val_accuracy: 0.3265
# Epoch 19/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3370 - accuracy: 1.0000 - val_loss: 5.6568 - val_accuracy: 0.3061
# Epoch 20/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2978 - accuracy: 1.0000 - val_loss: 6.3238 - val_accuracy: 0.2857
# Epoch 21/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2659 - accuracy: 1.0000 - val_loss: 5.4113 - val_accuracy: 0.3061
# 2/2 [==============================] - 3s 1s/step
# Epoch 1/200
# 7/7 [==============================] - 12s 2s/step - loss: 172.8214 - accuracy: 0.5949 - val_loss: 1.7406 - val_accuracy: 0.7755
# Epoch 2/200
# 7/7 [==============================] - 11s 2s/step - loss: 90.3365 - accuracy: 0.6974 - val_loss: 1.6643 - val_accuracy: 0.7347
# Epoch 3/200
# 7/7 [==============================] - 11s 2s/step - loss: 30.7915 - accuracy: 0.8308 - val_loss: 1.4335 - val_accuracy: 0.6939
# Epoch 4/200
# 7/7 [==============================] - 11s 2s/step - loss: 21.6364 - accuracy: 0.8308 - val_loss: 1.0656 - val_accuracy: 0.7143
# Epoch 5/200
# 7/7 [==============================] - 11s 2s/step - loss: 10.9210 - accuracy: 0.9231 - val_loss: 1.5261 - val_accuracy: 0.6327
# Epoch 6/200
# 7/7 [==============================] - 11s 2s/step - loss: 18.1205 - accuracy: 0.8410 - val_loss: 1.0440 - val_accuracy: 0.7347
# Epoch 7/200
# 7/7 [==============================] - 11s 2s/step - loss: 7.8516 - accuracy: 0.9436 - val_loss: 1.0796 - val_accuracy: 0.7143
# Epoch 8/200
# 7/7 [==============================] - 11s 2s/step - loss: 5.8218 - accuracy: 0.9487 - val_loss: 1.1087 - val_accuracy: 0.6939
# Epoch 9/200
# 7/7 [==============================] - 11s 2s/step - loss: 7.5337 - accuracy: 0.9487 - val_loss: 2.0494 - val_accuracy: 0.5714
# Epoch 10/200
# 7/7 [==============================] - 11s 2s/step - loss: 3.9630 - accuracy: 0.9641 - val_loss: 1.3577 - val_accuracy: 0.6939
# Epoch 11/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.8724 - accuracy: 0.9897 - val_loss: 1.9036 - val_accuracy: 0.5918
# Epoch 12/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.4637 - accuracy: 1.0000 - val_loss: 1.4025 - val_accuracy: 0.6531
# Epoch 13/200
# 7/7 [==============================] - 11s 2s/step - loss: 1.6641 - accuracy: 0.9949 - val_loss: 1.2953 - val_accuracy: 0.6939
# Epoch 14/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.7310 - accuracy: 1.0000 - val_loss: 1.2717 - val_accuracy: 0.6735
# Epoch 15/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.5642 - accuracy: 1.0000 - val_loss: 1.5374 - val_accuracy: 0.6531
# Epoch 16/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4270 - accuracy: 1.0000 - val_loss: 1.4621 - val_accuracy: 0.6735
# Epoch 17/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3788 - accuracy: 1.0000 - val_loss: 1.4570 - val_accuracy: 0.6735
# Epoch 18/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.4400 - accuracy: 1.0000 - val_loss: 1.5184 - val_accuracy: 0.6735
# Epoch 19/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.3118 - accuracy: 1.0000 - val_loss: 1.6727 - val_accuracy: 0.6735
# Epoch 20/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2813 - accuracy: 1.0000 - val_loss: 1.4880 - val_accuracy: 0.6735
# Epoch 21/200
# 7/7 [==============================] - 11s 2s/step - loss: 0.2650 - accuracy: 1.0000 - val_loss: 1.4823 - val_accuracy: 0.6735
# 2/2 [==============================] - 3s 1s/step

# %%
print(y_pred)
# Out:
# [[9.69879150e-01 3.01208645e-02]
#  [9.95329499e-01 4.67053941e-03]
#  [8.07312489e-01 1.92687526e-01]
#  [9.93349254e-01 6.65078359e-03]
#  [9.83241558e-01 1.67584252e-02]
#  [9.91730034e-01 8.26991163e-03]
#  [8.69777560e-01 1.30222440e-01]
#  [9.86177444e-01 1.38225872e-02]
#  [9.36205804e-01 6.37941733e-02]
#  [9.91876483e-01 8.12354125e-03]
#  [8.39747071e-01 1.60252944e-01]
#  [8.74606609e-01 1.25393435e-01]
#  [9.83824849e-01 1.61751751e-02]
#  [9.50480342e-01 4.95196246e-02]
#  [9.68110740e-01 3.18891928e-02]
#  [9.90308821e-01 9.69117228e-03]
#  [9.99999046e-01 9.83890004e-07]
#  [9.99987483e-01 1.25544693e-05]
#  [9.32455242e-01 6.75447732e-02]
#  [9.92385983e-01 7.61395320e-03]
#  [8.98333549e-01 1.01666413e-01]
#  [9.97267127e-01 2.73292605e-03]
#  [8.63883197e-01 1.36116803e-01]
#  [9.79189992e-01 2.08100677e-02]
#  [9.10952866e-01 8.90471637e-02]
#  [9.61839378e-01 3.81606258e-02]
#  [9.95438397e-01 4.56163846e-03]
#  [9.97002780e-01 2.99716159e-03]
#  [9.77627516e-01 2.23725028e-02]
#  [9.62240875e-01 3.77591811e-02]
#  [7.64389277e-01 2.35610753e-01]
#  [9.91319597e-01 8.68044887e-03]
#  [9.77516770e-01 2.24831961e-02]
#  [9.84213829e-01 1.57861449e-02]
#  [9.79769468e-01 2.02305671e-02]
#  [9.84046400e-01 1.59536041e-02]
#  [7.57878363e-01 2.42121577e-01]
#  [9.94983673e-01 5.01630222e-03]
#  [9.89270151e-01 1.07298670e-02]
#  [9.93543625e-01 6.45633135e-03]
#  [1.00000000e+00 1.13324096e-12]
#  [9.50283349e-01 4.97166477e-02]
#  [7.29649216e-02 9.27035093e-01]
#  [7.42779255e-01 2.57220715e-01]
#  [9.91451085e-01 8.54894519e-03]
#  [9.55015063e-01 4.49849181e-02]
#  [2.03216169e-03 9.97967780e-01]
#  [9.82926488e-01 1.70735773e-02]
#  [9.91637051e-01 8.36292095e-03]
#  [9.92747128e-01 7.25285523e-03]
#  [9.91470158e-01 8.52986984e-03]
#  [9.99999881e-01 1.26450928e-07]
#  [4.18782800e-01 5.81217229e-01]
#  [9.99355137e-01 6.44903921e-04]
#  [9.99992967e-01 7.02102489e-06]
#  [9.99996305e-01 3.66213726e-06]
#  [9.99999881e-01 1.74411952e-07]
#  [9.99989271e-01 1.07601991e-05]
#  [9.99971509e-01 2.84878242e-05]
#  [9.99997258e-01 2.70088071e-06]
#  [9.97954607e-01 2.04532081e-03]
#  [9.99999285e-01 6.96136681e-07]
#  [9.99686360e-01 3.13702592e-04]
#  [9.99999285e-01 7.57766486e-07]
#  [9.99933720e-01 6.63073661e-05]
#  [9.99998808e-01 1.19416347e-06]
#  [9.99892831e-01 1.07200322e-04]
#  [9.91800487e-01 8.19950365e-03]
#  [9.99998569e-01 1.39668020e-06]
#  [9.99845386e-01 1.54596113e-04]
#  [1.00000000e+00 3.18858788e-08]
#  [1.00000000e+00 4.35616709e-10]
#  [9.99966383e-01 3.36005760e-05]
#  [9.99772608e-01 2.27413431e-04]
#  [9.99235392e-01 7.64603494e-04]
#  [9.99564707e-01 4.35282302e-04]
#  [1.00000000e+00 4.96003842e-08]
#  [1.00000000e+00 4.86696088e-08]
#  [9.99772966e-01 2.27085169e-04]
#  [9.31669712e-01 6.83302954e-02]
#  [9.99975920e-01 2.41309244e-05]
#  [9.83171403e-01 1.68285742e-02]
#  [7.10942030e-01 2.89058059e-01]
#  [9.99855995e-01 1.44015226e-04]
#  [1.00000000e+00 3.59476164e-12]
#  [1.00000000e+00 2.26189228e-12]
#  [9.99999166e-01 8.24349172e-07]
#  [9.89774466e-01 1.02255270e-02]
#  [9.99987721e-01 1.22361716e-05]
#  [9.99748647e-01 2.51336751e-04]
#  [9.99997735e-01 2.26484690e-06]
#  [1.00000000e+00 2.81505402e-10]
#  [9.99620795e-01 3.79160221e-04]
#  [9.99991059e-01 8.97864084e-06]
#  [1.00000000e+00 1.87757632e-08]
#  [9.99999881e-01 7.42473958e-08]]

# %%
print(len(y_pred)==len(y))
# Out:
# True

# %% [markdown]
# **MÉTRICAS DE EVALUACIÓN**

# %%
y_pred_bin = []

for e in y_pred:
    if e[0]>e[1]:
        y_pred_bin.append(0)
    else:
        y_pred_bin.append(1)

# %%
roc_score = roc_auc_score(y, y_pred_bin, multi_class='ovr')

print(roc_score)
# Out:
# 0.4920833333333334

# %%
matriz = confusion_matrix(y, y_pred_bin)

print(matriz)
# Out:
# [[213  12]
#  [ 77   3]]

# %%
f1 = f1_score(y, y_pred_bin, average='weighted')

print(f1)
# Out:
# 0.6267840538797255
