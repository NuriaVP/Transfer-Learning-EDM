# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report  
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications import EfficientNetB0

# %%
color = 'rgb' #'grayscale' o 'rgb'
batch = 64
escala = 752

# %%
def combine_generator(gen1, gen2):
    while True:
        tupla1 = next(gen1)
        tupla2 = next(gen2)
        
        array_img_1 = tupla1[0]
        array_labels_1 = tupla1[1]
        
        array_img_2 = tupla2[0]
        array_labels_2 = tupla2[1]
        
        arrays_img = np.concatenate((array_img_1,array_img_2))
        arrays_labels = np.concatenate((array_labels_1,array_labels_2))
        
        yield(tuple((arrays_img,arrays_labels)))

# %%
def transferLearning_crossval_5(red, rutabla):
   
    train_datagen = ImageDataGenerator(
        rescale = 1./255,
        validation_split = 0.2
    )

    train_generator_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )
    
    train_generator_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K5/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )
    
    train_generator_2_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_2_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_2_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K2/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )
    
    train_generator_3_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_3_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K3/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_1 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_2 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_3_3 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )
    
    train_generator_4_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_4 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_5 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_6 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_7 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )

    train_generator_4_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32), 
        seed = 42,
        subset='training'
    )
    
    val_generator_4_8 = train_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K4/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        class_mode='categorical',
        batch_size = int(batch/32),
        seed = 42,
        subset='validation'
    )


    train_generator = combine_generator(train_generator_1, train_generator_2)
    train_generator = combine_generator(train_generator, train_generator_3)
    train_generator = combine_generator(train_generator, train_generator_4)
    train_generator = combine_generator(train_generator, train_generator_5)
    train_generator = combine_generator(train_generator, train_generator_6)
    train_generator = combine_generator(train_generator, train_generator_7)
    train_generator = combine_generator(train_generator, train_generator_8)
    train_generator = combine_generator(train_generator, train_generator_1_1)
    train_generator = combine_generator(train_generator, train_generator_1_2)
    train_generator = combine_generator(train_generator, train_generator_1_3)
    train_generator = combine_generator(train_generator, train_generator_1_4)
    train_generator = combine_generator(train_generator, train_generator_1_5)
    train_generator = combine_generator(train_generator, train_generator_1_6)
    train_generator = combine_generator(train_generator, train_generator_1_7)
    train_generator = combine_generator(train_generator, train_generator_1_8)
    train_generator = combine_generator(train_generator, train_generator_2_1)
    train_generator = combine_generator(train_generator, train_generator_2_2)
    train_generator = combine_generator(train_generator, train_generator_2_3)
    train_generator = combine_generator(train_generator, train_generator_2_4)
    train_generator = combine_generator(train_generator, train_generator_2_5)
    train_generator = combine_generator(train_generator, train_generator_2_6)
    train_generator = combine_generator(train_generator, train_generator_2_7)
    train_generator = combine_generator(train_generator, train_generator_2_8)
    train_generator = combine_generator(train_generator, train_generator_3_1)
    train_generator = combine_generator(train_generator, train_generator_3_2)
    train_generator = combine_generator(train_generator, train_generator_3_3)
    train_generator = combine_generator(train_generator, train_generator_3_4)
    train_generator = combine_generator(train_generator, train_generator_3_5)
    train_generator = combine_generator(train_generator, train_generator_3_6)
    train_generator = combine_generator(train_generator, train_generator_3_7)
    train_generator = combine_generator(train_generator, train_generator_3_8)
    train_generator = combine_generator(train_generator, train_generator_4_1)
    train_generator = combine_generator(train_generator, train_generator_4_2)
    train_generator = combine_generator(train_generator, train_generator_4_3)
    train_generator = combine_generator(train_generator, train_generator_4_4)
    train_generator = combine_generator(train_generator, train_generator_4_5)
    train_generator = combine_generator(train_generator, train_generator_4_6)
    train_generator = combine_generator(train_generator, train_generator_4_7)
    train_generator = combine_generator(train_generator, train_generator_4_8)
    val_generator = combine_generator(val_generator_1,val_generator_2)
    val_generator = combine_generator(val_generator,val_generator_3)
    val_generator = combine_generator(val_generator,val_generator_4)
    val_generator = combine_generator(val_generator,val_generator_5)
    val_generator = combine_generator(val_generator,val_generator_6)
    val_generator = combine_generator(val_generator,val_generator_7)
    val_generator = combine_generator(val_generator,val_generator_8)
    val_generator = combine_generator(val_generator,val_generator_1_1)
    val_generator = combine_generator(val_generator,val_generator_1_2)
    val_generator = combine_generator(val_generator,val_generator_1_3)
    val_generator = combine_generator(val_generator,val_generator_1_4)
    val_generator = combine_generator(val_generator,val_generator_1_5)
    val_generator = combine_generator(val_generator,val_generator_1_6)
    val_generator = combine_generator(val_generator,val_generator_1_7)
    val_generator = combine_generator(val_generator,val_generator_1_8)
    val_generator = combine_generator(val_generator,val_generator_2_1)
    val_generator = combine_generator(val_generator,val_generator_2_2)
    val_generator = combine_generator(val_generator,val_generator_2_3)
    val_generator = combine_generator(val_generator,val_generator_2_4)
    val_generator = combine_generator(val_generator,val_generator_2_5)
    val_generator = combine_generator(val_generator,val_generator_2_6)
    val_generator = combine_generator(val_generator,val_generator_2_7)
    val_generator = combine_generator(val_generator,val_generator_2_8)
    val_generator = combine_generator(val_generator,val_generator_3_1)
    val_generator = combine_generator(val_generator,val_generator_3_2)
    val_generator = combine_generator(val_generator,val_generator_3_3)
    val_generator = combine_generator(val_generator,val_generator_3_4)
    val_generator = combine_generator(val_generator,val_generator_3_5)
    val_generator = combine_generator(val_generator,val_generator_3_6)
    val_generator = combine_generator(val_generator,val_generator_3_7)
    val_generator = combine_generator(val_generator,val_generator_3_8)
    val_generator = combine_generator(val_generator,val_generator_4_1)
    val_generator = combine_generator(val_generator,val_generator_4_2)
    val_generator = combine_generator(val_generator,val_generator_4_3)
    val_generator = combine_generator(val_generator,val_generator_4_4)
    val_generator = combine_generator(val_generator,val_generator_4_5)
    val_generator = combine_generator(val_generator,val_generator_4_6)
    val_generator = combine_generator(val_generator,val_generator_4_7)
    val_generator = combine_generator(val_generator,val_generator_4_8)

    test_datagen = ImageDataGenerator(rescale=1./255)

    test_generator_1 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/iPhone/EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_2 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/iPhone/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_3 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/Samsung/EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_4 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/Samsung/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_5 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/OCT/EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_6 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/OCT/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_7 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/MESSIDOR/EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )

    test_generator_8 = test_datagen.flow_from_directory(
        directory = 'Datos Cross Validation EMD/K1/MESSIDOR/NO EMD',
        target_size = (escala,escala),
        color_mode = color,
        shuffle = False,
        class_mode='categorical',
        batch_size=1,
        seed = 42
    )
    
    test_generator = combine_generator(test_generator_1, test_generator_2)
    test_generator = combine_generator(test_generator, test_generator_3)
    test_generator = combine_generator(test_generator, test_generator_4)
    test_generator = combine_generator(test_generator, test_generator_5)
    test_generator = combine_generator(test_generator, test_generator_6)
    test_generator = combine_generator(test_generator, test_generator_7)
    test_generator = combine_generator(test_generator, test_generator_8)

    base_model = red(weights=None, include_top=False, input_shape=train_generator_1.image_shape)
    base_model.load_weights('Pesos/' + str(red).split(' ')[1] + '.h5')
    base_model.trainable = False ## Not trainable weights

    flatten_layer = layers.Flatten()
    dense_layer_1 = layers.Dense(1024, activation='relu')
    dense_layer_2 = layers.Dense(512, activation='relu')
    prediction_layer = layers.Dense(5, activation='softmax')


    model = models.Sequential([
        base_model,
        flatten_layer,
        dense_layer_1,
        dense_layer_2,
        prediction_layer
    ])
    
    #Definir compensador de pesos
    classes = np.unique(np.concatenate((train_generator_1.classes,train_generator_2.classes)))
    class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=classes, y=np.concatenate((train_generator_1.classes,train_generator_2.classes)))
    dic_class_weights = {0:class_weights[0], 1:class_weights[1]}
    
    #Entrenar el modelo
    model.compile(
        optimizer='Ftrl',
        loss='kl_divergence',
        metrics=['accuracy'],
    )

    es = EarlyStopping(monitor='val_loss', mode='min', patience=20,  restore_best_weights=True)

    #ahora el .fit acepta también generators como x
    history = model.fit(
        x = train_generator,
        batch_size=batch,
        epochs=200,
        callbacks=[es],
        validation_data = val_generator,
        class_weight = dic_class_weights
    )
    
    #Métricas de evaluación
    print('##########################################################################')
    print(f'MÉTRICAS DE EVALUACIÓN\n *Holdout\n *ClassWeights\n *Red: {red}\n *Test: {test}')
    print('##########################################################################')
    score_test = model.evaluate(x = test_generator, verbose = 0)
    print("Test loss:", score_test[0])
    print("Test accuracy:", score_test[1])
    
    y_test = test_generator.classes
    
    predictions = model.predict(test_generator)
    y_pred = list(map(lambda x: list(x).index(max(x)),predictions))

    matrix = confusion_matrix(y_test, y_pred)
    print(f"Matriz de confusión del modelo:\n\n{matrix}\n")
    
    f_score = f1_score(y_true = y_test, y_pred = y_pred, average = 'weighted')
    print(f"Valor de 'F1 score' del modelo: {f_score}\n")
    
    auc_roc = roc_auc_score(y_true = y_test, y_score = predictions, multi_class = 'ovr')
    print(f"Valor de 'AUC' del modelo: {auc_roc}\n")
    
    accuracy = accuracy_score(y_true = y_test, y_pred = y_pred)
    
    df_metricas = pd.read_csv(rutabla)
    
    df_metricas.iloc[[5], ['Accuracy']] = accuracy
    
    df_metricas.iloc[[5], ['F1-score']] = f_score
    
    df_metricas.iloc[[5], ['AUC']] = auc_roc
    
    return history

# %%
history_vgg16 = transferLearning_crossval_5(VGG16, 'metricas_cross_validation.csv')
